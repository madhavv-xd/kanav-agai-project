# %% [markdown]
# # Day 2 — Feature Engineering
#
# The pipeline creates:
# - IncomePerYearAtCompany
# - PromotionGapRatio
# - ExperienceRatio
# - SatisfactionIndex
#
# It also removes identifiers from model features and avoids post-outcome leakage.
