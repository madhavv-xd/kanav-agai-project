# %% [markdown]
# # Day 4 — Streamlit Dashboard
#
# Run:
#
# ```powershell
# streamlit run frontend/dashboard.py
# ```
#
# Dashboard includes KPI cards, department risk, risk distribution, skill gaps, recommendations and employee drill-down.
