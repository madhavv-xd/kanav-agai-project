# %% [markdown]
# # Day 2 — Model Versioning
#
# The MVP saves:
# `models/v1/attrition_pipeline.joblib`
# `models/v1/metadata.json`
#
# Metadata records algorithm, features and evaluation metrics. MLflow can be added after the baseline workflow is stable.
