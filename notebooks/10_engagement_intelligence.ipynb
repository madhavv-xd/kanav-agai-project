# %% [markdown]
# # Day 3 — Engagement Intelligence
#
# Use `cleaned_hr_data.csv` for engagement analytics.
#
# ```python
# hr.groupby("DepartmentType")["Engagement Score"].mean().sort_values()
# ```
#
# Do not falsely join its Employee ID to the attrition EmployeeNumber.
