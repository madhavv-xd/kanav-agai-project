# %% [markdown]
# # Day 2 — Baseline Model
#
# Baseline: Logistic Regression with class balancing.
#
# Metrics:
# Precision, Recall, F1, ROC-AUC.
#
# Run `python scripts/build_pipeline.py` to train and save the model.
