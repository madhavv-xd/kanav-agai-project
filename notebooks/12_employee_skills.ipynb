# %% [markdown]
# # Day 3 — Employee Skills
#
# No trustworthy current employee-skill dataset was uploaded.
#
# The MVP therefore creates `employee_skills_mvp_synthetic.csv` and labels every row `SYNTHETIC_MVP`.
#
# Replace this file with real employee skill evidence when available.
