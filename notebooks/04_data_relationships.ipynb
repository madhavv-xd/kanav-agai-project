# %% [markdown]
# # Day 1 — Data Relationships
#
# Verified O*NET relationships:
#
# `occupation_data` → `essential_skills` using `O*NET-SOC Code`
#
# `occupation_data` → `software_skills` using `O*NET-SOC Code`
#
# Employee IDs across the uploaded employee datasets were not proven compatible, so they are not joined.
