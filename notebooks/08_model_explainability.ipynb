# %% [markdown]
# # Day 2 — SHAP Explainability
#
# After baseline/model comparison is stable, add SHAP for:
# - global feature importance
# - local employee-level explanations
#
# For the current MVP, the saved pipeline is Logistic Regression; use SHAP's linear explainer or permutation-based explanations rather than TreeExplainer.
