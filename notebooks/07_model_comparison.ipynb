# %% [markdown]
# # Day 2 — Model Comparison
#
# Planned comparison:
# 1. Logistic Regression
# 2. Random Forest
# 3. XGBoost
#
# The current runnable MVP starts with Logistic Regression so the pipeline remains explainable and lightweight. Add RF/XGBoost after the baseline is verified.
