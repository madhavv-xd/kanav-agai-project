# %% [markdown]
# # Day 1 — Data Cleaning
#
# The executable pipeline is in `scripts/build_pipeline.py`.
#
# Cleaning includes:
# - trimming string whitespace
# - preserving raw CSVs
# - saving processed copies
# - generating a data-quality report
