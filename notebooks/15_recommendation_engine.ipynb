# %% [markdown]
# # Day 3 — Recommendation Engine
#
# MVP uses transparent rules mapping a missing skill to a learning recommendation.
#
# Later upgrade:
# sentence-transformer embeddings + cosine similarity against course descriptions.
