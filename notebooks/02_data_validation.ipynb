# %% [markdown]
# # Day 1 — Data Validation
#
# Validate schema, ranges, uniqueness and categories.
#
# ```python
# assert attr["Age"].between(18, 100).all()
# assert attr["EmployeeNumber"].is_unique
# assert set(attr["Attrition"].dropna().unique()) <= {"Yes", "No"}
# assert attr["MonthlyIncome"].gt(0).all()
# assert attr["WorkLifeBalance"].between(1, 4).all()
# ```
#
# The exact checks should be extended after inspecting every column.
