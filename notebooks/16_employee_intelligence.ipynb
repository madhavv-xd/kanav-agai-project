# %% [markdown]
# # Day 3 — Employee Intelligence
#
# The final business table is:
# EmployeeNumber | JobRole | Attrition_Prob | Risk | SkillGap | Recommendation
#
# Engagement is kept separate unless a verified common employee key is supplied.
